# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df_eventos = pd.read_csv('Eventos.csv')

# %%
df_artistas = pd.read_csv('Artistas.csv')

# %%
df_hospedajes_traslados = pd.read_csv('Hospedajes y traslados.csv')

# %%
df_tour = pd.read_csv('Tour.csv')

# %%
df_entradas = pd.read_csv('Entradas Cortesia.csv')

# %%
df_pais = pd.read_csv('pais.csv')

# %%
df_pais = df_pais.drop_duplicates()

# %%
df_pais
# Out:
#               Pais
# 0         ALEMANIA
# 2   ESTADOS UNIDOS
# 3           CANADA
# 4         AUTRALIA
# 8          ESPAÃ‘A
# 9          BELGICA
# 14           CHILE
# 18       ARGENTINA
# 23   NUEVA ZELANDA
# 44          BRASIL
# 74        COLOMBIA

# %%
df_pais = df_pais.reset_index()

# %%
df_pais
# Out:
#     index            Pais
# 0       0        ALEMANIA
# 1       2  ESTADOS UNIDOS
# 2       3          CANADA
# 3       4        AUTRALIA
# 4       8         ESPAÃ‘A
# 5       9         BELGICA
# 6      14           CHILE
# 7      18       ARGENTINA
# 8      23   NUEVA ZELANDA
# 9      44          BRASIL
# 10     74        COLOMBIA

# %%
df_pais = df_pais.rename_axis('id_pais')

# %%
df_pais = df_pais.drop(columns = ['index'])

# %%
df_pais
# Out:
#                    Pais
# id_pais
# 0              ALEMANIA
# 1        ESTADOS UNIDOS
# 2                CANADA
# 3              AUTRALIA
# 4               ESPAÃ‘A
# 5               BELGICA
# 6                 CHILE
# 7             ARGENTINA
# 8         NUEVA ZELANDA
# 9                BRASIL
# 10             COLOMBIA

# %%
df_pais
# Out:
#                    Pais
# id_pais
# 0              ALEMANIA
# 1        ESTADOS UNIDOS
# 2                CANADA
# 3              AUTRALIA
# 4               ESPAÃ‘A
# 5               BELGICA
# 6                 CHILE
# 7             ARGENTINA
# 8         NUEVA ZELANDA
# 9                BRASIL
# 10             COLOMBIA

# %%
df_pais = df_pais.rename(columns={'Pais': "nombre_pais"})

# %%
df_pais
# Out:
#             nombre_pais
# id_pais
# 0              ALEMANIA
# 1        ESTADOS UNIDOS
# 2                CANADA
# 3              AUTRALIA
# 4               ESPAÃ‘A
# 5               BELGICA
# 6                 CHILE
# 7             ARGENTINA
# 8         NUEVA ZELANDA
# 9                BRASIL
# 10             COLOMBIA

# %%
df_tour
# Out:
#                  nombre fecha inicio fecha termino
# 0        One Night Only   26/09/2017    08/10/2021
# 1              CARAVANA   29/07/2018    01/05/2019
# 2               S.U.N.O   16/06/2016    21/08/2018
# 3    Lively And Supreme   30/08/2018    09/11/2020
# 4        Bigger than me   28/07/2019    29/05/2021
# ..                  ...          ...           ...
# 187    How do you sleep   25/09/2021    14/09/2022
# 188      Bigger than me   28/07/2019    29/05/2021
# 189      Schulz Forever   22/02/2021    22/03/2022
# 190     Dangerous Woman   02/08/2018    22/07/2021
# 191     The After Hours   20/04/2018    11/04/2021
#
# [192 rows x 3 columns]

# %%
df_tour = df_tour.drop_duplicates()

# %%
df_tour
# Out:
#                           nombre fecha inicio fecha termino
# 0                 One Night Only   26/09/2017    08/10/2021
# 1                       CARAVANA   29/07/2018    01/05/2019
# 2                        S.U.N.O   16/06/2016    21/08/2018
# 3             Lively And Supreme   30/08/2018    09/11/2020
# 4                 Bigger than me   28/07/2019    29/05/2021
# 5                    Niño Blessi   09/08/2019    19/04/2020
# 6                       Gowlding   07/03/2019    17/12/2022
# 7              Twelve Carat Tour   29/01/2018    07/08/2022
# 10                     Mil Rosas   03/03/2016    29/11/2022
# 11               Dangerous Woman   02/08/2018    22/07/2021
# 12              How do you sleep   25/09/2021    14/09/2022
# 13                  Passionfruit   18/05/2017    10/10/2020
# 16                      A7S Show   19/12/2017    03/06/2019
# 17                    Get Jacked   16/01/2017    14/02/2021
# 18                           WAP   03/06/2016    23/12/2018
# ...

# %%
df_tour = df_tour.reset_index()

# %%
df_tour = df_tour.rename_axis('id_tour')

# %%
df_tour = df_tour.drop(columns = ['index'])

# %%
df_tour = df_tour.rename(columns={'fecha inicio': "fecha_inicio", 'fecha termino': "fecha_termino"})

# %%
df_tour
# Out:
#                               nombre fecha_inicio fecha_termino
# id_tour
# 0                     One Night Only   26/09/2017    08/10/2021
# 1                           CARAVANA   29/07/2018    01/05/2019
# 2                            S.U.N.O   16/06/2016    21/08/2018
# 3                 Lively And Supreme   30/08/2018    09/11/2020
# 4                     Bigger than me   28/07/2019    29/05/2021
# 5                        Niño Blessi   09/08/2019    19/04/2020
# 6                           Gowlding   07/03/2019    17/12/2022
# 7                  Twelve Carat Tour   29/01/2018    07/08/2022
# 8                          Mil Rosas   03/03/2016    29/11/2022
# 9                    Dangerous Woman   02/08/2018    22/07/2021
# 10                  How do you sleep   25/09/2021    14/09/2022
# 11                      Passionfruit   18/05/2017    10/10/2020
# 12                          A7S Show   19/12/2017    03/06/2019
# 13                        Get Jacked   16/01/2017    14/02/2021
# ...

# %%
df_productoras = pd.read_csv('Productoras.csv')

# %%
df_productoras
# Out:
#                                                 Nombre       País  Nº contacto
# 0                                     Ais producciones      CHILE  56987054160
# 1                       Cucarro producciones limitada       CHILE  56935039844
# 2           C&m musicos - musica y asesorias musicales      CHILE  56982842595
# 3                   Eventos comunidad ombligo limitada      CHILE  56938037004
# 4                                        Alto la torre      CHILE  56911128539
# ..                                                 ...        ...          ...
# 436                                           IndyRock     ESPAÑA  34911917911
# 437                                        Kibon video      CHILE  56992881968
# 438                              FEG ENTRETENIMIENTOS   ARGENTINA  54942915097
# 439  Producciones seven time entertainment group li...      CHILE  56931242846
# 440                             PROSPERO PRODUCCIONES   ARGENTINA  54981121681
#
# [441 rows x 3 columns]

# %%
df_productoras = df_productoras.drop_duplicates()

# %%
df_productoras = df_productoras.reset_index()

# %%
df_productoras = df_productoras.rename_axis('id_productora')

# %%
df_productoras = df_productoras.drop(columns = ['index'])

# %%
df_productoras
# Out:
#                                                    Nombre            País  \
# id_productora
# 0                                        Ais producciones           CHILE
# 1                          Cucarro producciones limitada            CHILE
# 2              C&m musicos - musica y asesorias musicales           CHILE
# 3                      Eventos comunidad ombligo limitada           CHILE
# 4                                           Alto la torre           CHILE
# ...                                                   ...             ...
# 241                              Event Production Company  ESTADOS UNIDOS
# 242                            Eveerlast Productions INC.  ESTADOS UNIDOS
# 243                                   Event Management NZ   NUEVA ZELANDA
# 244                              Nikkita producciones spa           CHILE
# 245                                              IndyRock          ESPAÑA
#
#                Nº contacto
# id_productora
# ...

# %%
df_productoras = df_productoras.rename(columns={'Nombre': "nombre", 'Nº contacto': "telefono"})

# %%
df_productoras
# Out:
#                                                    nombre            País  \
# id_productora
# 0                                        Ais producciones           CHILE
# 1                          Cucarro producciones limitada            CHILE
# 2              C&m musicos - musica y asesorias musicales           CHILE
# 3                      Eventos comunidad ombligo limitada           CHILE
# 4                                           Alto la torre           CHILE
# ...                                                   ...             ...
# 241                              Event Production Company  ESTADOS UNIDOS
# 242                            Eveerlast Productions INC.  ESTADOS UNIDOS
# 243                                   Event Management NZ   NUEVA ZELANDA
# 244                              Nikkita producciones spa           CHILE
# 245                                              IndyRock          ESPAÑA
#
#                   telefono
# id_productora
# ...

# %%
df_productoras
# Out:
#                                                    nombre     telefono
# id_productora
# 0                                        Ais producciones  56987054160
# 1                          Cucarro producciones limitada   56935039844
# 2              C&m musicos - musica y asesorias musicales  56982842595
# 3                      Eventos comunidad ombligo limitada  56938037004
# 4                                           Alto la torre  56911128539
# ...                                                   ...          ...
# 241                              Event Production Company    114142196
# 242                            Eveerlast Productions INC.    151359131
# 243                                   Event Management NZ   6445721253
# 244                              Nikkita producciones spa  56996308812
# 245                                              IndyRock  34911917911
#
# [246 rows x 2 columns]

# %%
df_eventos = df_eventos.drop_duplicates()

# %%
df_eventos = df_eventos.reset_index()

# %%
df_eventos = df_eventos.rename_axis('id_evento')

# %%
df_eventos = df_eventos.drop(columns = ['index'])

# %%
df_eventos
# Out:
#                          Evento            nombre_lugar       Artista  \
# id_evento
# 0                     BZRP Tour  Pabellon Max Schmeling  Paulo Londra
# 1          Como si no importara      Arena Ludwingsburg        Emilia
# 2                 Born this way            Irving Plaza     Lady Gaga
# 3                    El Duko2.0             Thunder Bay          Duki
# 4                  LOS APARATOS  Tarpeian Precinct Lawn        Trueno
# ...                         ...                     ...           ...
# 228                      El J23    Canadian Tire Centre     Jordan 23
# 229              One Night Only           WIZink Center      Bee Gees
# 230                      Voyage        Studio The Venue          ABBA
# 231               Born this way         Shubert Theatre     Lady Gaga
# 232                  Get Jacked    Carrer Baix Vinalopo      Afrojack
#
#                  ciudad fecha_evento                Productora
# id_evento
# ...

# %%
# Out:
#                          Productora        ciudad
# id_evento
# 0                Nachhaltige Events        BERLIN
# 1                      fullevent.de  LUDWINGSBURG
# 2                           CSI DMC    NUEVA YORK
# 3                         EventsEye       ONTARIO
# 4                     YouTOOProject        SYDNEY
# ...                             ...           ...
# 228              Mayam Producciones        OTTAWA
# 229          Producciones Baltimore        MADRID
# 230            Leading Event Agency      AUCKLAND
# 231        Event Production Company        BOSTON
# 232          Producciones Baltimore       MISLATA
#
# [233 rows x 2 columns]

# %%
df_event['id_productora'] = df_eventos.apply(add_productora_id, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\trini\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# c:\users\trini\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\trini\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ciudad'
#
# ...

# %%
df_eventos.to_csv('Eventos_casi.csv', index = True)

# %%
df_productoras.to_csv('productoras_casi.csv', index = True)

# %%
df_eventos = pd.read_csv('Eventos_casi.csv')

# %%
df_eventos
# Out:
#      id_evento                Evento            nombre_lugar       Artista  \
# 0            0             BZRP Tour  Pabellon Max Schmeling  Paulo Londra
# 1            1  Como si no importara      Arena Ludwingsburg        Emilia
# 2            2         Born this way            Irving Plaza     Lady Gaga
# 3            3            El Duko2.0             Thunder Bay          Duki
# 4            4          LOS APARATOS  Tarpeian Precinct Lawn        Trueno
# ..         ...                   ...                     ...           ...
# 228        228                El J23    Canadian Tire Centre     Jordan 23
# 229        229        One Night Only           WIZink Center      Bee Gees
# 230        230                Voyage        Studio The Venue          ABBA
# 231        231         Born this way         Shubert Theatre     Lady Gaga
# 232        232            Get Jacked    Carrer Baix Vinalopo      Afrojack
#
# ...

# %%
df_tour.to_csv('tour_casii.csv', index = True)

# %%
df_eventos_limpios = pd.read_csv('eventos_limpio.csv')

# %%
df_eventos_limpios
# Out:
#      id_evento            nombre_lugar        ciudad fecha_evento  \
# 0            0  Pabellon Max Schmeling        BERLIN        44079
# 1            1      Arena Ludwingsburg  LUDWINGSBURG   23-01-2021
# 2            2            Irving Plaza    NUEVA YORK        44174
# 3            3             Thunder Bay       ONTARIO   29-07-2020
# 4            4  Tarpeian Precinct Lawn        SYDNEY        43442
# ..         ...                     ...           ...          ...
# 228        228    Canadian Tire Centre        OTTAWA        44022
# 229        229           WIZink Center        MADRID   26-09-2017
# 230        230        Studio The Venue      AUCKLAND   29-05-2020
# 231        231         Shubert Theatre        BOSTON        42952
# 232        232    Carrer Baix Vinalopo       MISLATA   14-02-2021
#
#      id_productora  id_tour
# 0              227      NaN
# 1               10      NaN
# 2               92     17.0
# 3               80      NaN
# ...

# %%
df_ciudad = pd.read_csv('ciudad.csv')

# %%
df_ciudad
# Out:
#            ciudad
# 0          BERLIN
# 1    LUDWINGSBURG
# 2      NUEVA YORK
# 3         ONTARIO
# 4          SYDNEY
# ..            ...
# 228        OTTAWA
# 229        MADRID
# 230      AUCKLAND
# 231        BOSTON
# 232       MISLATA
#
# [233 rows x 1 columns]

# %%
df_ciudad = df_ciudad.drop_duplicates()

# %%
df_ciudad
# Out:
#              ciudad
# 0            BERLIN
# 1      LUDWINGSBURG
# 2        NUEVA YORK
# 3           ONTARIO
# 4            SYDNEY
# 5        SACRAMENTO
# 6           COLOGNE
# 8            BILBAO
# 9            FOREST
# 10            TEXAS
# 14    VIÃ‘A DEL MAR
# 15         VALENCIA
# 16         SANTIAGO
# 17         BRUSELAS
# 18     BUENOS AIRES
# 20          MISLATA
# 22         AUCKLAND
# 25           MUNICH
# 29       VALPARAISO
# 30           MADRID
# 32          TORONTO
# 39           OSTEND
# 40        BARCELONA
# 42   RIO DE JANEIRO
# 44         BRASILIA
# 46    WASHINGTON DC
# 49      LOS ANGELES
# 50        FRANKFURT
# 60       WELLINGTON
# 61       LOWER HUTT
# 66           BOSTON
# 68           BOGOTA
# 72     PHILADELPHIA
# 80        SAO PAULO
# 87          HAMBURG
# 98         HAMILTON
# 109          NELSON
# 110         HANOVER
# 173        MEDELLIN
# 228          OTTAWA

# %%
df_ciudad = df_ciudad.reset_index()

# %%
df_ciudad
# Out:
#     index          ciudad
# 0       0          BERLIN
# 1       1    LUDWINGSBURG
# 2       2      NUEVA YORK
# 3       3         ONTARIO
# 4       4          SYDNEY
# 5       5      SACRAMENTO
# 6       6         COLOGNE
# 7       8          BILBAO
# 8       9          FOREST
# 9      10           TEXAS
# 10     14   VIÃ‘A DEL MAR
# 11     15        VALENCIA
# 12     16        SANTIAGO
# 13     17        BRUSELAS
# 14     18    BUENOS AIRES
# 15     20         MISLATA
# 16     22        AUCKLAND
# 17     25          MUNICH
# 18     29      VALPARAISO
# 19     30          MADRID
# 20     32         TORONTO
# 21     39          OSTEND
# 22     40       BARCELONA
# 23     42  RIO DE JANEIRO
# 24     44        BRASILIA
# 25     46   WASHINGTON DC
# 26     49     LOS ANGELES
# 27     50       FRANKFURT
# 28     60      WELLINGTON
# 29     61      LOWER HUTT
# 30     66          BOSTON
# 31     68          BOGOTA
# 32     72    PHILADELPHIA
# 33     80       SAO PAULO
# ...

# %%
df_ciudad = df_ciudad.rename_axis('id_ciudad')

# %%
df_ciudad = df_ciudad.drop(columns=['index'])

# %%
df_ciudad
# Out:
#                    ciudad
# id_ciudad
# 0                  BERLIN
# 1            LUDWINGSBURG
# 2              NUEVA YORK
# 3                 ONTARIO
# 4                  SYDNEY
# 5              SACRAMENTO
# 6                 COLOGNE
# 7                  BILBAO
# 8                  FOREST
# 9                   TEXAS
# 10          VIÃ‘A DEL MAR
# 11               VALENCIA
# 12               SANTIAGO
# 13               BRUSELAS
# 14           BUENOS AIRES
# 15                MISLATA
# 16               AUCKLAND
# 17                 MUNICH
# 18             VALPARAISO
# 19                 MADRID
# 20                TORONTO
# 21                 OSTEND
# 22              BARCELONA
# 23         RIO DE JANEIRO
# 24               BRASILIA
# 25          WASHINGTON DC
# 26            LOS ANGELES
# 27              FRANKFURT
# 28             WELLINGTON
# 29             LOWER HUTT
# 30                 BOSTON
# 31                 BOGOTA
# 32           PHILADELPHIA
# 33              SAO PAULO
# ...

# %%
df_ciudad = df_ciudad.to_csv('ciudad_limpio.csv', index = True)

# %%
df_pais = df_pais.to_csv('pais_limpio.csv', index = True)

# %%
df_entradas
# Out:
#                 evento asiento        artista
# 0              Bangerz     D15    Miley Cyrus
# 1       I Aint Worried     A17   One Republic
# 2          Show Forest     A12  One Direction
# 3            Bang Bang     C30       Jessie J
# 4             DJ Snake     D12       DJ Snake
# ..                 ...     ...            ...
# 433                WAP      B8        Cardi B
# 434  Super Freaky Girl     C15    Nicki Minaj
# 435       Passionfruit      C8          Drake
# 436             Voyage     B20           ABBA
# 437  Beyond Wonderland      A6     Marshmello
#
# [438 rows x 3 columns]

# %%
df_entradas.reset_index()
# Out:
#      index             evento asiento        artista
# 0        0            Bangerz     D15    Miley Cyrus
# 1        1     I Aint Worried     A17   One Republic
# 2        2        Show Forest     A12  One Direction
# 3        3          Bang Bang     C30       Jessie J
# 4        4           DJ Snake     D12       DJ Snake
# ..     ...                ...     ...            ...
# 433    433                WAP      B8        Cardi B
# 434    434  Super Freaky Girl     C15    Nicki Minaj
# 435    435       Passionfruit      C8          Drake
# 436    436             Voyage     B20           ABBA
# 437    437  Beyond Wonderland      A6     Marshmello
#
# [438 rows x 4 columns]

# %%
df_entradas = df_entradas.drop_duplicates()

# %%
df_entradas = df_entradas.reset_index()

# %%
df_entradas = df_entradas.rename_axis('id_entrada')

# %%
df_entradas = df_entradas.drop(columns=['index'])

# %%
df_entradas
# Out:
#                          evento asiento                artista
# id_entrada
# 0                       Bangerz     D15            Miley Cyrus
# 1                I Aint Worried     A17           One Republic
# 2                   Show Forest     A12          One Direction
# 3                     Bang Bang     C30               Jessie J
# 4                      DJ Snake     D12               DJ Snake
# ...                         ...     ...                    ...
# 140         Say you wont let go     A30           James Arthur
# 141                   Epic Show     A29  The Martinez Brothers
# 142                     Que oso     B28                   Snow
# 143                  Fruta y te      C0                   Gepe
# 144           Beyond Wonderland     D26             Marshmello
#
# [145 rows x 3 columns]

# %%
df_artistas
# Out:
#      nombre_escenido inicio_carrera   telefono
# 0               Duki     14/02/2019  947967523
# 1    Backstreet Boys     23/01/1994  933555053
# 2    Michael Jackson       4/2/1980  973673018
# 3        Mon Laferte     18/07/2008  982606150
# 4               Khea     16/06/2013  927484546
# ..               ...            ...        ...
# 459            Ozuna       5/1/2006  984218361
# 460         Hardwell     18/04/2004  967614670
# 461  Backstreet Boys     23/01/1994  933555053
# 462             Cami      10/6/2016  919240255
# 463        Radiohead       8/7/1986  924174144
#
# [464 rows x 3 columns]

# %%
df_artistas = df_artistas.drop_duplicates()

# %%
df_artistas = df_artistas.reset_index()

# %%
df_artistas = df_artistas.rename_axis('id_artista')

# %%
df_artistas
# Out:
#             index       nombre_escenido inicio_carrera   telefono
# id_artista
# 0               0                  Duki     14/02/2019  947967523
# 1               1       Backstreet Boys     23/01/1994  933555053
# 2               2       Michael Jackson       4/2/1980  973673018
# 3               3           Mon Laferte     18/07/2008  982606150
# 4               4                  Khea     16/06/2013  927484546
# ...           ...                   ...            ...        ...
# 195           374  La Oreja de Van Gogh       8/3/2001  966357123
# 196           378              Bizarrap     11/12/2017  957841287
# 197           397           Nicki Minaj       2/7/2010  975557868
# 198           411                Camila     26/06/2009  965638977
# 199           441         Mercedes Sosa     29/05/1982  963954428
#
# [200 rows x 4 columns]

# %%
df_artistas = df_artistas.drop(columns=['index'])

# %%
df_artistas
# Out:
#                  nombre_escenido inicio_carrera   telefono
# id_artista
# 0                           Duki     14/02/2019  947967523
# 1                Backstreet Boys     23/01/1994  933555053
# 2                Michael Jackson       4/2/1980  973673018
# 3                    Mon Laferte     18/07/2008  982606150
# 4                           Khea     16/06/2013  927484546
# ...                          ...            ...        ...
# 195         La Oreja de Van Gogh       8/3/2001  966357123
# 196                     Bizarrap     11/12/2017  957841287
# 197                  Nicki Minaj       2/7/2010  975557868
# 198                       Camila     26/06/2009  965638977
# 199                Mercedes Sosa     29/05/1982  963954428
#
# [200 rows x 3 columns]

# %%
df_artistas = df_artistas.to_csv('artistas_casi.csv', index = True)

# %%
df_hospedajes_traslados = df_hospedajes_traslados.to_csv('Hospedajes_traslados.csv', index = True)

# %%
df_hospedajes_trasla = pd.read_csv('Hospedajes_traslados.csv')

# %%
df_hospedajes_trasla = df_hospedajes_trasla.drop_duplicates()

# %%
df_hospedajes_traslados
# Out:
#      Unnamed: 0 codigo reserva        artista fecha inicio fecha termino  \
# 0             0      DUE-45195   Paulo Londra    18/4/2019     23/4/2019
# 1             1      VJA-35509  Lali Esposito    16/4/2019     17/4/2019
# 2             2      YOP-65177    Niall Horan     5/5/2020      9/5/2020
# 3             3      NOA-92813       Bon Jovi     9/1/2018     12/1/2018
# 4             4      OFF-75731       Bon Jovi     6/3/2022     10/3/2022
# ..          ...            ...            ...          ...           ...
# 395         395      ZHJ-26410         Hansen     2/4/2018      5/4/2018
# 396         396      LUP-45712         Trueno    23/2/2018     28/2/2018
# 397         397      USW-12442        El Alfa    1/10/2022     1/10/2022
# 398         398      EJG-79027            Wos    29/5/2019      4/6/2019
# 399         399      TQR-16323  Princesa Alba   17/10/2018    19/10/2018
#
#             lugar        nombre hotel tipo traslado  \
# ...

# %%
df_entradas = df_entradas.drop_duplicates()

# %%
df_entradas = df_entradas.reset_index()

# %%
df_enntradas = df_entradas.rename_axis('id_entrada')

# %%
df_entradas = df_enntradas.drop(columns =['index'])

# %%
df_entradas
# Out:
#                          evento asiento                artista
# id_entrada
# 0                       Bangerz     D15            Miley Cyrus
# 1                I Aint Worried     A17           One Republic
# 2                   Show Forest     A12          One Direction
# 3                     Bang Bang     C30               Jessie J
# 4                      DJ Snake     D12               DJ Snake
# ...                         ...     ...                    ...
# 140         Say you wont let go     A30           James Arthur
# 141                   Epic Show     A29  The Martinez Brothers
# 142                     Que oso     B28                   Snow
# 143                  Fruta y te      C0                   Gepe
# 144           Beyond Wonderland     D26             Marshmello
#
# [145 rows x 3 columns]

# %%
df_entradas.to_csv('entradas_casi.csv')

# %%
df_pais
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25572/2884371857.py in <module>
# ----> 1 df_pais
#
# NameError: name 'df_pais' is not defined
